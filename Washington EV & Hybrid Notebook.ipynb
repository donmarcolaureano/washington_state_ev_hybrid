# %%
import pandas as pd

# %%
ev_hybrid_all = pd.read_csv('/Users/marcolaureano2/Documents/GitHub/washington_state_ev_hybrid/Data/Electric_Vehicle_Population_Data.csv')

# %%
ev_hybrid_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186879 entries, 0 to 186878
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         186879 non-null  object
#  1   County                                             186876 non-null  object
#  2   City                                               186876 non-null  object
#  3   State                                              186879 non-null  object
#  4   Postal Code                                        186876 non-null  float64
#  5   Model Year                                         186879 non-null  int64
#  6   Make                                               186879 non-null  object
#  7   Model                                              186879 non-null  object
# ...

# %%
ev_hybrid_all
# Out:
#         VIN (1-10)     County            City State  Postal Code  Model Year  \
# 0       WBY8P6C58K       King         Seattle    WA      98115.0        2019
# 1       5YJSA1DN4D     Kitsap       Bremerton    WA      98312.0        2013
# 2       5YJSA1E26J       King            Kent    WA      98042.0        2018
# 3       WBY2Z2C54E       King        Bellevue    WA      98004.0        2014
# 4       5YJXCDE23J       King        Bellevue    WA      98004.0        2018
# ...            ...        ...             ...   ...          ...         ...
# 186874  JTMEB3FVXM  Snohomish       Arlington    WA      98223.0        2021
# 186875  7SAYGAEEXP  Snohomish        Stanwood    WA      98292.0        2023
# 186876  3FA6P0SUXK       King          Auburn    WA      98001.0        2019
# 186877  7SAYGDEE1P     Pierce          Tacoma    WA      98422.0        2023
# 186878  7SAYGDEE1R    Douglas  East Wenatchee    WA      98802.0        2024
#
# ...

# %%
ev_hybrid_all['Make'].unique()
# Out:
# array(['BMW', 'TESLA', 'VOLKSWAGEN', 'FIAT', 'NISSAN', 'CHEVROLET', 'KIA',
#        'JAGUAR', 'SMART', 'VOLVO', 'JEEP', 'LEXUS', 'AUDI', 'HYUNDAI',
#        'CHRYSLER', 'FORD', 'PORSCHE', 'MITSUBISHI', 'TOYOTA', 'RIVIAN',
#        'HONDA', 'MAZDA', 'MINI', 'LINCOLN', 'SUBARU', 'CADILLAC',
#        'GENESIS', 'POLESTAR', 'MERCEDES-BENZ', 'LAND ROVER', 'LUCID',
#        'FISKER', 'ALFA ROMEO', 'DODGE', 'GMC', 'TH!NK', 'BENTLEY',
#        'AZURE DYNAMICS', 'ROLLS ROYCE', 'WHEEGO ELECTRIC CARS'],
#       dtype=object)

# %%
ev_hybrid_all['Electric Vehicle Type'].unique()
# Out:
# array(['Battery Electric Vehicle (BEV)',
#        'Plug-in Hybrid Electric Vehicle (PHEV)'], dtype=object)

# %%
ev_hybrid_simple = ev_hybrid_all.drop(['Postal Code', 'DOL Vehicle ID', 'State', 'Base MSRP', 'Vehicle Location', '2020 Census Tract', 'Legislative District'], axis = 1)

# %%
ev_hybrid_simple = ev_hybrid_simple.set_index('VIN (1-10)')

# %%
ev_hybrid_simple
# Out:
#                County            City  Model Year    Make       Model  \
# VIN (1-10)
# WBY8P6C58K       King         Seattle        2019     BMW          I3
# 5YJSA1DN4D     Kitsap       Bremerton        2013   TESLA     MODEL S
# 5YJSA1E26J       King            Kent        2018   TESLA     MODEL S
# WBY2Z2C54E       King        Bellevue        2014     BMW          I8
# 5YJXCDE23J       King        Bellevue        2018   TESLA     MODEL X
# ...               ...             ...         ...     ...         ...
# JTMEB3FVXM  Snohomish       Arlington        2021  TOYOTA  RAV4 PRIME
# 7SAYGAEEXP  Snohomish        Stanwood        2023   TESLA     MODEL Y
# 3FA6P0SUXK       King          Auburn        2019    FORD      FUSION
# 7SAYGDEE1P     Pierce          Tacoma        2023   TESLA     MODEL Y
# 7SAYGDEE1R    Douglas  East Wenatchee        2024   TESLA     MODEL Y
#
#                              Electric Vehicle Type  \
# VIN (1-10)
# ...

# %%
ev_hybrid_simple = ev_hybrid_simple.drop(['Electric Utility'], axis = 1)

# %%
ev_hybrid_simple
# Out:
#                County            City  Model Year    Make       Model  \
# VIN (1-10)
# WBY8P6C58K       King         Seattle        2019     BMW          I3
# 5YJSA1DN4D     Kitsap       Bremerton        2013   TESLA     MODEL S
# 5YJSA1E26J       King            Kent        2018   TESLA     MODEL S
# WBY2Z2C54E       King        Bellevue        2014     BMW          I8
# 5YJXCDE23J       King        Bellevue        2018   TESLA     MODEL X
# ...               ...             ...         ...     ...         ...
# JTMEB3FVXM  Snohomish       Arlington        2021  TOYOTA  RAV4 PRIME
# 7SAYGAEEXP  Snohomish        Stanwood        2023   TESLA     MODEL Y
# 3FA6P0SUXK       King          Auburn        2019    FORD      FUSION
# 7SAYGDEE1P     Pierce          Tacoma        2023   TESLA     MODEL Y
# 7SAYGDEE1R    Douglas  East Wenatchee        2024   TESLA     MODEL Y
#
#                              Electric Vehicle Type  \
# VIN (1-10)
# ...
